# %% [markdown]
# # 📌 Guía para entender y visualizar datos con Python
#
# Bienvenido a esta breve lección que te brindará **sugerencias y recomendaciones** para que aproveches al máximo el curso.
#
# ---
#
# ## 📓 Uso intensivo de Jupyter Notebooks
#
# - El curso se basa en **Jupyter Notebooks** para ilustrar y demostrar conceptos vistos en las clases.
# - Los Notebooks aparecen generalmente **después** de los videos, lecturas y evaluaciones de cada semana.
#
# ---
#
# ## 🗓️ Semana uno: Estructura típica
#
# - Encontrarás:
#   - Videos y lecturas.
#   - Un prompt de discusión.
#   - Varios quizzes.
#   - Finalmente, los Notebooks para practicar.
#
# ---
#
# ## ⚡ Consejo clave: No esperes para abrir los Notebooks
#
# - Abre los Notebooks **mientras ves los videos**.
# - Mantén los Notebooks abiertos en paralelo para:
#   - Pausar el video.
#   - Probar en el Notebook lo que vas aprendiendo.
# - Este enfoque ayuda a **consolidar la información** y mejorar tu comprensión práctica en Python.
#
# ---
#
# ## 🖥️ Recomendaciones para tu espacio de trabajo
#
# - Si tienes un monitor grande o varios monitores:
#   - Usa uno para los videos.
#   - Usa otro para los Notebooks.
# - Ejemplo de workspace recomendado:
#   - Pantalla derecha: video de un miembro del equipo explicando conceptos (e.g., cómo cambiar el kernel en Jupyter).
#   - Pantalla izquierda: tu Notebook abierto para seguir paso a paso.
#
# ---
#
# ## 🔎 Comprender los datos y su origen
#
# - Un enfoque central del curso es entender:
#   - Qué son los datos.
#   - Tipos de datos.
#   - De dónde provienen los datos.
# - Conocer la **fuente de los datos** es esencial para preparar un análisis confiable.
#
# 🗓️ En la semana 4:
# - Aprenderás sobre:
#   - Origen de los datos.
#   - Cómo seleccionar muestras.
#   - Cómo considerar el diseño muestral en el análisis de datos.
#
# - Consejo: aprovecha las preguntas interactivas dentro de los videos; te ayudarán a **concretar los conceptos**.
#
# ---
#
# ## 💬 Preguntas y foros
#
# - Puedes enviar tus preguntas sobre el contenido.
# - Aunque no siempre se responderán de inmediato, se archivarán en la sección de **FAQs**, beneficiando a futuros estudiantes.
# - Las preguntas más simples se resuelven rápido en los **foros de discusión**, pero **no dudes en hacer preguntas complejas**, serán canalizadas a los instructores.
#
# ---
#
# ## 📚 Lecturas adicionales
#
# - Hemos identificado temas que suelen ser más difíciles para algunos estudiantes.
# - Revisa la sección **Lecturas Adicionales** en los recursos del curso para aclarar estos temas.
#
# ---
#
# ## 🚀 ¡Disfruta el contenido!
#
# Esperamos que estas pautas te ayuden a **sacarle el máximo provecho** al increíble contenido que te espera en este curso de estadísticas y visualización con Python.
