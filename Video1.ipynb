# %% [markdown]
# Notas sobre el curso Understanding and Visualizing Data with Python que se da en la plataforma coursera por parte de la universidad de Michigan

# %% [markdown]
# # 📊 Bienvenido al curso: Entendiendo y Visualizando Estadísticas con Python
#
# Este curso es el primero de una especialización más grande sobre **estadísticas con Python**. Cada curso se construirá sobre el anterior, dándote una visión completa y práctica de la estadística.
#
# ---
#
# ## ✨ Objetivo general del curso
#
# - Brindarte una visión **bien redondeada** de qué es la estadística y cómo aplicarla usando Python.
# - Aprenderás tanto teoría como práctica, con múltiples datasets y ejemplos reales.
# - Desarrollarás habilidades para **visualizar**, **resumir** y **comunicar** resultados estadísticos.
#
# ---
#
# ## 🗂️ Estructura del curso
#
# El curso está dividido en **cuatro partes** principales:
#
# ### 🔹 Parte 1: Introducción a Estadística y Datos
# - ¿Qué es la estadística?
# - ¿Qué son los datos?
# - La estadística como una disciplina de “gran carpa” con diversas perspectivas.
# - Reflexionarás sobre cómo usas datos en tu vida diaria.
# - Introducción a **Jupyter Notebooks** y fundamentos de Python.
#
# ### 🔹 Parte 2 y Parte 3: Análisis y Resumen de Datos
# - Trabajarás con distintos datasets para:
#   - Resumir datos **gráficamente** y **numéricamente**.
#   - Explorar métodos de resumen **univariados** y **multivariados**.
# - Ejercicios prácticos con datasets como:
#   - Datos sobre cartwheels (sí, el equipo hizo volteretas en el trabajo).
#   - Estudio de pizzas (harás análisis y escribirás resultados).
#
# ### 🔹 Parte 4: Probabilidad e Inferencia Estadística
# - Introducción a:
#   - **Muestreo probabilístico**.
#   - Métodos para usar una muestra y **hacer inferencias** sobre poblaciones mayores.
#
# ---
#
# ## 📝 Perspectivas sobre la estadística
#
# Durante el curso, escucharás a varios miembros del equipo que compartirán cómo aplican la estadística en el mundo real. Esto te ayudará a ver la **variedad de enfoques y aplicaciones** que tiene la estadística.
#
# ---
#
# ## 🎯 Qué aprenderás
#
# - Conceptos clave de estadística descriptiva e inferencial.
# - Uso de Python para análisis estadístico.
# - Visualización efectiva de datos.
# - Interpretación y comunicación de resultados estadísticos.
# - Introducción a la inferencia a partir de muestras.
#
# ---
#
# ## 🧑‍💻 Programación y herramientas
#
# - Uso básico e intermedio de **Python**.
# - Introducción y práctica con **Jupyter Notebooks**.
# - Ejercicios prácticos con datasets reales.
# - Uso de **aplicaciones web (applets)** para reforzar conceptos.
#
# ---
#
# ## ✅ Evaluación y recursos
#
# - A lo largo del curso, tendrás oportunidades para:
#   - Evaluar tu aprendizaje con ejercicios prácticos.
#   - Acceder a recursos adicionales para profundizar en los temas.
#   - Desarrollar habilidades comunicativas escribiendo análisis de datos.
# - Cada módulo incluye **tutoriales en Python** y tareas para aplicar lo aprendido.
#
# ---
#
# ## 🚀 ¡Comencemos!
#
# ¡Estamos emocionados de que inicies tu experiencia en estadísticas! Prepárate para descubrir lo emocionante que puede ser el análisis de datos y cómo Python te ayudará a explorar y entender el mundo de la estadística.
